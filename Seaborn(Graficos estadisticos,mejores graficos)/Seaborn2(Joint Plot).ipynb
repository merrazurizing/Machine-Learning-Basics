# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy as sp
import seaborn as sb

#Importa base de datos
database = sb.load_dataset('tips')

# %%
# argumentos (la X ,la Y, los datos)
sb.jointplot(x='tip',y='total_bill',data=database)
plt.show()
